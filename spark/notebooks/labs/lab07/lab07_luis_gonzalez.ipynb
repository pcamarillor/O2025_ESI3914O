# %% [markdown]
# # <center> <img src="../../img/ITESOLogo.png" alt="ITESO" width="480" height="130"> </center>
# # <center> **Departamento de Electrónica, Sistemas e Informática** </center>
# ---
# ## <center> Computer Systems Engineering  </center>
# ---
# ### <center> Big Data Processing </center>
# ---
# #### <center> **Autumn 2025** </center>
# ---
#
# **Lab 07**: Structured Streaming with Files
#
# **Date**: October 9nd 2025
#
# **Student Name**: Luis Alberto González Escamilla
#
# **Professor**: Pablo Camarillo Ramirez

# %%
import findspark
findspark.init()

from pyspark.sql import SparkSession
from pyspark.sql.functions import col, count, when, avg, sum as spark_sum
from luis_gonzalez.spark_utils import SparkUtils

spark = SparkSession.builder \
    .appName("Lab07") \
    .master("spark://45d2b62a9e1b:7077") \
    .config("spark.ui.port", "4040") \
    .getOrCreate()

sc = spark.sparkContext
sc.setLogLevel("ERROR")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/10/13 23:39:48 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
logs_schema = SparkUtils.generate_schema([
    ("server_id", "string"),
    ("status_code", "int"),
    ("response_time_ms", "double"),
    ("cpu_usage", "double"),
    ("memory_usage", "double")
])

print("Schema generated.")
# Out:
# Schema generated.

# %%
LOG_DIR = "/opt/spark/work-dir/lib/luis_gonzalez/logs/"

streaming_logs = spark.readStream \
    .schema(logs_schema) \
    .format("json") \
    .option("maxFilesPerTrigger", 1) \
    .option("pathGlobFilter", "server_logs_*.json") \
    .load(LOG_DIR)

# %%
analyzed_logs = streaming_logs \
    .withColumn("error_type",
                when(col("status_code") == 200, "SUCCESS")
                .when(col("status_code") == 404, "NOT_FOUND")
                .when(col("status_code") == 500, "INTERNAL_ERROR")
                .when(col("status_code") == 503, "SERVICE_UNAVAILABLE")
                .otherwise("UNKNOWN")) \
    .withColumn("is_error", 
                when(col("status_code") >= 400, True).otherwise(False)) \
    .withColumn("is_critical",
                when((col("status_code") == 500) | 
                     (col("cpu_usage") > 90) | 
                     (col("memory_usage") > 85), True)
                .otherwise(False)) \
    .withColumn("performance_status",
                when(col("response_time_ms") > 500, "SLOW")
                .when(col("response_time_ms") > 300, "MODERATE")
                .otherwise("FAST"))
# Out:
# -------------------------------------------
# Batch: 31
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-002|200        |SUCCESS            |909.64          |SLOW              |30.72    |85.7        |true       |
# |SERVER-001|500        |INTERNAL_ERROR     |685.82          |SLOW              |62.45    |70.2        |true       |
# |SERVER-004|503        |SERVICE_UNAVAILABLE|750.79          |SLOW              |54.07    |39.76       |false      |
# |SERVER-001|200        |SUCCESS            |552.46          |SLOW              |57.89    |67.54       |false      |
# |SERVER-005|200        |SUCCESS            |808.33          |SLOW              |59.68    |20.61       |false      |
# |SERVER-004|200        |SUCCESS            |205.57          |FAST              |78.42    |69.17       |false      |
# |SERVER-001|200        |SUCCESS            |574.53          |SLOW              |58.49    |29.81       |false      |
# |SERVER-001|404        |NOT_FOUND          |213.31          |FAST              |77.0     |35.51       |false      |
# |SERVER-002|200        |SUCCESS            |726.8           |SLOW              |64.53    |24.98       |false      |
# |SERVER-003|200        |SUCCESS            |200.41          |FAST              |30.06    |72.84       |false      |
# |SERVER-004|200        |SUCCESS            |753.07          |SLOW              |46.81    |29.63       |false      |
# |SERVER-002|200        |SUCCESS            |474.56          |MODERATE          |81.71    |38.48       |false      |
# |SERVER-001|200        |SUCCESS            |664.95          |SLOW              |44.75    |29.73       |false      |
# |SERVER-003|200        |SUCCESS            |614.66          |SLOW              |16.57    |29.53       |false      |
# |SERVER-003|200        |SUCCESS            |883.72          |SLOW              |26.64    |47.19       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 31
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-002|200        |SUCCESS       |909.64          |30.72    |85.7        |
# |SERVER-001|500        |INTERNAL_ERROR|685.82          |62.45    |70.2        |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 32
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-002|200        |SUCCESS            |512.17          |SLOW              |16.89    |89.08       |true       |
# |SERVER-004|503        |SERVICE_UNAVAILABLE|744.39          |SLOW              |87.9     |57.26       |false      |
# |SERVER-003|200        |SUCCESS            |162.75          |FAST              |35.04    |59.31       |false      |
# |SERVER-002|200        |SUCCESS            |830.94          |SLOW              |32.07    |33.93       |false      |
# |SERVER-003|503        |SERVICE_UNAVAILABLE|177.81          |FAST              |28.67    |34.39       |false      |
# |SERVER-005|404        |NOT_FOUND          |742.79          |SLOW              |25.9     |35.36       |false      |
# |SERVER-002|503        |SERVICE_UNAVAILABLE|267.49          |FAST              |75.35    |75.15       |false      |
# |SERVER-003|200        |SUCCESS            |515.38          |SLOW              |37.17    |84.29       |false      |
# |SERVER-001|200        |SUCCESS            |933.34          |SLOW              |17.29    |47.11       |false      |
# |SERVER-004|503        |SERVICE_UNAVAILABLE|716.71          |SLOW              |86.42    |81.06       |false      |
# |SERVER-001|200        |SUCCESS            |86.81           |FAST              |39.92    |48.86       |false      |
# |SERVER-002|200        |SUCCESS            |229.51          |FAST              |69.72    |73.19       |false      |
# |SERVER-004|200        |SUCCESS            |628.27          |SLOW              |25.11    |25.79       |false      |
# |SERVER-001|503        |SERVICE_UNAVAILABLE|485.42          |MODERATE          |19.95    |58.47       |false      |
# |SERVER-005|404        |NOT_FOUND          |808.8           |SLOW              |87.72    |29.67       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 32
# -------------------------------------------
# +----------+-----------+----------+----------------+---------+------------+
# |server_id |status_code|error_type|response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+----------+----------------+---------+------------+
# |SERVER-002|200        |SUCCESS   |512.17          |16.89    |89.08       |
# +----------+-----------+----------+----------------+---------+------------+

# %%
query_all = analyzed_logs \
    .select("server_id", "status_code", "error_type", 
            "response_time_ms", "performance_status", 
            "cpu_usage", "memory_usage", "is_critical") \
    .writeStream \
    .outputMode("append") \
    .format("console") \
    .option("truncate", "false") \
    .start()

query_all.awaitTermination(5)
query_all.stop()
# Out:
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-004|200        |SUCCESS            |145.58          |FAST              |36.24    |56.24       |false      |
# |SERVER-003|500        |INTERNAL_ERROR     |53.14           |FAST              |68.23    |27.32       |true       |
# |SERVER-003|200        |SUCCESS            |982.52          |SLOW              |19.35    |76.83       |false      |
# |SERVER-001|404        |NOT_FOUND          |871.67          |SLOW              |94.22    |48.63       |true       |
# |SERVER-005|200        |SUCCESS            |81.48           |FAST              |85.26    |80.2        |false      |
# |SERVER-004|200        |SUCCESS            |101.82          |FAST              |15.5     |62.59       |false      |
# |SERVER-005|200        |SUCCESS            |260.83          |FAST              |55.45    |30.49       |false      |
# |SERVER-001|200        |SUCCESS            |942.82          |SLOW              |83.24    |50.66       |false      |
# |SERVER-002|200        |SUCCESS            |189.13          |FAST              |45.26    |70.08       |false      |
# |SERVER-001|200        |SUCCESS            |148.4           |FAST              |94.4     |83.69       |true       |
# |SERVER-001|200        |SUCCESS            |412.7           |MODERATE          |91.94    |88.12       |true       |
# |SERVER-004|200        |SUCCESS            |308.57          |MODERATE          |12.34    |64.11       |false      |
# |SERVER-002|500        |INTERNAL_ERROR     |859.44          |SLOW              |30.85    |22.33       |true       |
# |SERVER-005|200        |SUCCESS            |519.54          |SLOW              |58.57    |34.93       |false      |
# |SERVER-003|503        |SERVICE_UNAVAILABLE|666.3           |SLOW              |59.39    |57.07       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-002|200        |SUCCESS            |722.82          |SLOW              |20.9     |31.92       |false      |
# |SERVER-005|404        |NOT_FOUND          |905.54          |SLOW              |49.29    |29.11       |false      |
# |SERVER-005|200        |SUCCESS            |902.64          |SLOW              |10.27    |74.39       |false      |
# |SERVER-001|200        |SUCCESS            |709.54          |SLOW              |38.54    |28.8        |false      |
# |SERVER-003|200        |SUCCESS            |214.63          |FAST              |29.38    |74.3        |false      |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|886.36          |SLOW              |35.93    |52.4        |false      |
# |SERVER-002|200        |SUCCESS            |781.17          |SLOW              |92.96    |69.02       |true       |
# |SERVER-003|200        |SUCCESS            |321.51          |MODERATE          |41.96    |64.11       |false      |
# |SERVER-002|200        |SUCCESS            |563.93          |SLOW              |19.88    |51.37       |false      |
# |SERVER-001|200        |SUCCESS            |522.72          |SLOW              |88.77    |85.75       |true       |
# |SERVER-005|200        |SUCCESS            |55.85           |FAST              |44.78    |23.53       |false      |
# |SERVER-002|200        |SUCCESS            |278.48          |FAST              |39.48    |22.24       |false      |
# |SERVER-003|503        |SERVICE_UNAVAILABLE|325.26          |MODERATE          |12.97    |63.01       |false      |
# |SERVER-002|200        |SUCCESS            |923.0           |SLOW              |55.21    |71.3        |false      |
# |SERVER-005|200        |SUCCESS            |670.91          |SLOW              |80.44    |57.81       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-001|200        |SUCCESS            |653.33          |SLOW              |90.84    |62.9        |true       |
# |SERVER-004|503        |SERVICE_UNAVAILABLE|92.4            |FAST              |25.19    |36.35       |false      |
# |SERVER-002|200        |SUCCESS            |577.78          |SLOW              |71.22    |61.71       |false      |
# |SERVER-002|500        |INTERNAL_ERROR     |496.86          |MODERATE          |42.47    |25.98       |true       |
# |SERVER-005|200        |SUCCESS            |595.52          |SLOW              |29.64    |28.72       |false      |
# |SERVER-002|200        |SUCCESS            |498.7           |MODERATE          |75.73    |42.4        |false      |
# |SERVER-001|200        |SUCCESS            |113.05          |FAST              |30.12    |59.24       |false      |
# |SERVER-002|200        |SUCCESS            |87.58           |FAST              |91.71    |26.29       |true       |
# |SERVER-004|200        |SUCCESS            |565.2           |SLOW              |30.6     |73.1        |false      |
# |SERVER-002|200        |SUCCESS            |901.83          |SLOW              |35.49    |20.13       |false      |
# |SERVER-002|200        |SUCCESS            |413.7           |MODERATE          |86.03    |36.0        |false      |
# |SERVER-004|404        |NOT_FOUND          |871.74          |SLOW              |84.05    |48.56       |false      |
# |SERVER-001|200        |SUCCESS            |988.36          |SLOW              |84.57    |79.23       |false      |
# |SERVER-005|200        |SUCCESS            |386.59          |MODERATE          |10.41    |38.36       |false      |
# |SERVER-005|200        |SUCCESS            |729.49          |SLOW              |45.66    |74.07       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-002|500        |INTERNAL_ERROR     |377.24          |MODERATE          |67.43    |50.79       |true       |
# |SERVER-005|200        |SUCCESS            |661.17          |SLOW              |35.95    |37.68       |false      |
# |SERVER-004|200        |SUCCESS            |382.08          |MODERATE          |27.13    |47.01       |false      |
# |SERVER-001|200        |SUCCESS            |990.43          |SLOW              |44.73    |58.62       |false      |
# |SERVER-001|200        |SUCCESS            |895.22          |SLOW              |70.16    |89.67       |true       |
# |SERVER-005|404        |NOT_FOUND          |702.83          |SLOW              |88.7     |53.9        |false      |
# |SERVER-005|200        |SUCCESS            |722.59          |SLOW              |52.97    |51.98       |false      |
# |SERVER-003|503        |SERVICE_UNAVAILABLE|190.78          |FAST              |32.16    |73.65       |false      |
# |SERVER-005|200        |SUCCESS            |108.93          |FAST              |57.76    |58.46       |false      |
# |SERVER-003|200        |SUCCESS            |291.4           |FAST              |12.04    |44.12       |false      |
# |SERVER-001|404        |NOT_FOUND          |590.7           |SLOW              |85.39    |65.55       |false      |
# |SERVER-001|503        |SERVICE_UNAVAILABLE|233.38          |FAST              |80.87    |62.29       |false      |
# |SERVER-001|200        |SUCCESS            |703.04          |SLOW              |11.83    |54.59       |false      |
# |SERVER-004|500        |INTERNAL_ERROR     |891.42          |SLOW              |84.76    |37.96       |true       |
# |SERVER-003|404        |NOT_FOUND          |495.72          |MODERATE          |35.28    |43.08       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 33
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-002|500        |INTERNAL_ERROR     |739.82          |SLOW              |79.49    |58.65       |true       |
# |SERVER-002|200        |SUCCESS            |340.85          |MODERATE          |34.66    |23.56       |false      |
# |SERVER-005|200        |SUCCESS            |958.7           |SLOW              |76.51    |72.63       |false      |
# |SERVER-004|500        |INTERNAL_ERROR     |854.61          |SLOW              |77.16    |27.35       |true       |
# |SERVER-001|200        |SUCCESS            |909.95          |SLOW              |55.13    |59.27       |false      |
# |SERVER-001|200        |SUCCESS            |947.1           |SLOW              |87.26    |33.4        |false      |
# |SERVER-004|500        |INTERNAL_ERROR     |613.8           |SLOW              |89.26    |29.44       |true       |
# |SERVER-003|200        |SUCCESS            |489.35          |MODERATE          |71.98    |36.41       |false      |
# |SERVER-003|200        |SUCCESS            |714.73          |SLOW              |54.67    |39.25       |false      |
# |SERVER-004|500        |INTERNAL_ERROR     |51.65           |FAST              |15.75    |57.29       |true       |
# |SERVER-004|200        |SUCCESS            |340.01          |MODERATE          |39.17    |51.07       |false      |
# |SERVER-003|503        |SERVICE_UNAVAILABLE|463.97          |MODERATE          |43.18    |69.8        |false      |
# |SERVER-004|200        |SUCCESS            |363.29          |MODERATE          |10.59    |42.33       |false      |
# |SERVER-004|404        |NOT_FOUND          |673.23          |SLOW              |47.79    |53.38       |false      |
# |SERVER-002|500        |INTERNAL_ERROR     |769.89          |SLOW              |65.87    |66.79       |true       |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 33
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-002|500        |INTERNAL_ERROR|739.82          |79.49    |58.65       |
# |SERVER-004|500        |INTERNAL_ERROR|854.61          |77.16    |27.35       |
# |SERVER-004|500        |INTERNAL_ERROR|613.8           |89.26    |29.44       |
# |SERVER-004|500        |INTERNAL_ERROR|51.65           |15.75    |57.29       |
# |SERVER-002|500        |INTERNAL_ERROR|769.89          |65.87    |66.79       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type    |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
# |SERVER-002|200        |SUCCESS       |563.07          |SLOW              |90.23    |46.0        |true       |
# |SERVER-001|200        |SUCCESS       |83.8            |FAST              |91.79    |41.94       |true       |
# |SERVER-003|200        |SUCCESS       |750.99          |SLOW              |85.59    |46.41       |false      |
# |SERVER-005|200        |SUCCESS       |224.12          |FAST              |40.68    |54.18       |false      |
# |SERVER-002|200        |SUCCESS       |873.21          |SLOW              |50.49    |46.83       |false      |
# |SERVER-003|200        |SUCCESS       |810.18          |SLOW              |65.59    |26.69       |false      |
# |SERVER-005|500        |INTERNAL_ERROR|324.63          |MODERATE          |33.65    |36.36       |true       |
# |SERVER-001|200        |SUCCESS       |677.87          |SLOW              |33.3     |50.83       |false      |
# |SERVER-002|200        |SUCCESS       |593.28          |SLOW              |17.82    |61.77       |false      |
# |SERVER-004|200        |SUCCESS       |138.08          |FAST              |37.03    |72.15       |false      |
# |SERVER-002|500        |INTERNAL_ERROR|807.08          |SLOW              |72.59    |44.59       |true       |
# |SERVER-003|200        |SUCCESS       |651.2           |SLOW              |84.33    |56.33       |false      |
# |SERVER-005|200        |SUCCESS       |484.77          |MODERATE          |47.44    |35.93       |false      |
# |SERVER-003|200        |SUCCESS       |772.86          |SLOW              |27.88    |26.37       |false      |
# |SERVER-004|200        |SUCCESS       |617.54          |SLOW              |82.25    |24.17       |false      |
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-001|200        |SUCCESS            |342.01          |MODERATE          |68.12    |24.58       |false      |
# |SERVER-001|500        |INTERNAL_ERROR     |583.95          |SLOW              |78.23    |32.72       |true       |
# |SERVER-005|200        |SUCCESS            |338.13          |MODERATE          |43.7     |80.04       |false      |
# |SERVER-004|404        |NOT_FOUND          |518.08          |SLOW              |43.7     |64.01       |false      |
# |SERVER-001|200        |SUCCESS            |443.76          |MODERATE          |37.47    |87.41       |true       |
# |SERVER-001|503        |SERVICE_UNAVAILABLE|486.05          |MODERATE          |86.74    |30.4        |false      |
# |SERVER-003|200        |SUCCESS            |170.12          |FAST              |40.76    |20.05       |false      |
# |SERVER-005|404        |NOT_FOUND          |391.69          |MODERATE          |66.43    |20.85       |false      |
# |SERVER-003|200        |SUCCESS            |748.82          |SLOW              |17.54    |24.87       |false      |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|444.1           |MODERATE          |57.06    |42.18       |false      |
# |SERVER-002|200        |SUCCESS            |337.31          |MODERATE          |62.4     |68.35       |false      |
# |SERVER-001|404        |NOT_FOUND          |829.17          |SLOW              |71.1     |45.93       |false      |
# |SERVER-002|200        |SUCCESS            |331.17          |MODERATE          |33.47    |23.86       |false      |
# |SERVER-003|200        |SUCCESS            |537.74          |SLOW              |77.06    |40.97       |false      |
# |SERVER-004|200        |SUCCESS            |866.5           |SLOW              |21.88    |52.37       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-002|404        |NOT_FOUND          |678.23          |SLOW              |52.54    |29.04       |false      |
# |SERVER-005|404        |NOT_FOUND          |337.29          |MODERATE          |77.51    |24.2        |false      |
# |SERVER-003|500        |INTERNAL_ERROR     |877.27          |SLOW              |74.95    |69.64       |true       |
# |SERVER-002|200        |SUCCESS            |786.3           |SLOW              |58.21    |75.99       |false      |
# |SERVER-004|200        |SUCCESS            |145.83          |FAST              |28.85    |34.52       |false      |
# |SERVER-001|200        |SUCCESS            |747.87          |SLOW              |12.58    |75.04       |false      |
# |SERVER-001|200        |SUCCESS            |337.55          |MODERATE          |26.51    |62.54       |false      |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|919.75          |SLOW              |70.77    |32.85       |false      |
# |SERVER-001|500        |INTERNAL_ERROR     |877.04          |SLOW              |60.8     |71.47       |true       |
# |SERVER-002|404        |NOT_FOUND          |492.86          |MODERATE          |32.17    |37.12       |false      |
# |SERVER-005|200        |SUCCESS            |743.14          |SLOW              |24.7     |50.92       |false      |
# |SERVER-004|200        |SUCCESS            |467.24          |MODERATE          |28.3     |70.18       |false      |
# |SERVER-003|200        |SUCCESS            |850.73          |SLOW              |55.38    |49.28       |false      |
# |SERVER-004|200        |SUCCESS            |215.59          |FAST              |37.39    |37.45       |false      |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|814.14          |SLOW              |62.83    |32.83       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 7
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-003|200        |SUCCESS            |919.94          |SLOW              |25.0     |67.17       |false      |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|145.98          |FAST              |35.67    |71.96       |false      |
# |SERVER-002|200        |SUCCESS            |946.56          |SLOW              |89.81    |84.68       |false      |
# |SERVER-002|200        |SUCCESS            |51.21           |FAST              |91.1     |29.46       |true       |
# |SERVER-001|200        |SUCCESS            |309.15          |MODERATE          |59.8     |26.92       |false      |
# |SERVER-004|200        |SUCCESS            |107.88          |FAST              |35.61    |62.32       |false      |
# |SERVER-002|500        |INTERNAL_ERROR     |91.22           |FAST              |52.95    |52.93       |true       |
# |SERVER-001|200        |SUCCESS            |596.4           |SLOW              |32.0     |63.57       |false      |
# |SERVER-004|200        |SUCCESS            |799.67          |SLOW              |67.84    |32.2        |false      |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|899.91          |SLOW              |84.16    |36.86       |false      |
# |SERVER-001|200        |SUCCESS            |711.85          |SLOW              |12.09    |45.16       |false      |
# |SERVER-005|200        |SUCCESS            |678.41          |SLOW              |28.45    |88.52       |true       |
# |SERVER-004|200        |SUCCESS            |460.33          |MODERATE          |25.69    |30.91       |false      |
# |SERVER-003|200        |SUCCESS            |542.01          |SLOW              |26.09    |33.52       |false      |
# |SERVER-001|404        |NOT_FOUND          |950.44          |SLOW              |22.96    |55.07       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 8
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-003|200        |SUCCESS            |355.05          |MODERATE          |54.82    |31.75       |false      |
# |SERVER-004|200        |SUCCESS            |90.82           |FAST              |74.36    |85.35       |true       |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|138.75          |FAST              |71.72    |75.03       |false      |
# |SERVER-004|404        |NOT_FOUND          |997.21          |SLOW              |23.88    |49.88       |false      |
# |SERVER-003|200        |SUCCESS            |73.58           |FAST              |69.38    |73.35       |false      |
# |SERVER-005|200        |SUCCESS            |189.24          |FAST              |38.82    |64.13       |false      |
# |SERVER-001|200        |SUCCESS            |429.18          |MODERATE          |20.38    |27.42       |false      |
# |SERVER-001|500        |INTERNAL_ERROR     |733.27          |SLOW              |40.99    |52.15       |true       |
# |SERVER-004|200        |SUCCESS            |496.86          |MODERATE          |79.06    |65.33       |false      |
# |SERVER-001|200        |SUCCESS            |515.58          |SLOW              |64.52    |25.53       |false      |
# |SERVER-002|404        |NOT_FOUND          |559.25          |SLOW              |68.83    |22.97       |false      |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|919.88          |SLOW              |38.14    |54.96       |false      |
# |SERVER-003|503        |SERVICE_UNAVAILABLE|100.7           |FAST              |40.03    |57.86       |false      |
# |SERVER-002|200        |SUCCESS            |285.51          |FAST              |93.03    |58.76       |true       |
# |SERVER-001|500        |INTERNAL_ERROR     |435.68          |MODERATE          |16.29    |68.5        |true       |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 9
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-004|503        |SERVICE_UNAVAILABLE|449.18          |MODERATE          |57.07    |25.11       |false      |
# |SERVER-002|200        |SUCCESS            |649.58          |SLOW              |92.18    |85.8        |true       |
# |SERVER-003|503        |SERVICE_UNAVAILABLE|85.93           |FAST              |85.61    |51.6        |false      |
# |SERVER-001|500        |INTERNAL_ERROR     |240.67          |FAST              |51.08    |49.33       |true       |
# |SERVER-001|503        |SERVICE_UNAVAILABLE|386.41          |MODERATE          |87.79    |80.4        |false      |
# |SERVER-004|200        |SUCCESS            |182.47          |FAST              |70.61    |22.07       |false      |
# |SERVER-004|200        |SUCCESS            |497.19          |MODERATE          |41.42    |79.51       |false      |
# |SERVER-001|200        |SUCCESS            |891.14          |SLOW              |47.69    |55.69       |false      |
# |SERVER-004|404        |NOT_FOUND          |424.03          |MODERATE          |72.24    |49.74       |false      |
# |SERVER-004|200        |SUCCESS            |919.01          |SLOW              |81.98    |74.58       |false      |
# |SERVER-004|503        |SERVICE_UNAVAILABLE|937.09          |SLOW              |53.2     |76.91       |false      |
# |SERVER-005|200        |SUCCESS            |429.54          |MODERATE          |31.95    |51.43       |false      |
# |SERVER-005|200        |SUCCESS            |90.65           |FAST              |21.87    |63.79       |false      |
# |SERVER-001|200        |SUCCESS            |933.84          |SLOW              |56.02    |83.08       |false      |
# |SERVER-004|200        |SUCCESS            |80.43           |FAST              |37.17    |54.75       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 10
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-004|503        |SERVICE_UNAVAILABLE|90.36           |FAST              |83.26    |82.14       |false      |
# |SERVER-001|404        |NOT_FOUND          |439.35          |MODERATE          |14.53    |75.49       |false      |
# |SERVER-001|200        |SUCCESS            |186.08          |FAST              |35.96    |48.42       |false      |
# |SERVER-005|200        |SUCCESS            |772.32          |SLOW              |41.84    |43.22       |false      |
# |SERVER-005|200        |SUCCESS            |73.54           |FAST              |84.19    |35.96       |false      |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|467.47          |MODERATE          |51.86    |44.81       |false      |
# |SERVER-004|200        |SUCCESS            |501.25          |SLOW              |39.21    |84.68       |false      |
# |SERVER-005|200        |SUCCESS            |243.12          |FAST              |75.68    |25.35       |false      |
# |SERVER-004|404        |NOT_FOUND          |161.62          |FAST              |59.05    |21.75       |false      |
# |SERVER-003|200        |SUCCESS            |101.72          |FAST              |65.9     |72.39       |false      |
# |SERVER-002|404        |NOT_FOUND          |72.81           |FAST              |12.07    |61.68       |false      |
# |SERVER-004|200        |SUCCESS            |913.9           |SLOW              |64.19    |45.35       |false      |
# |SERVER-005|200        |SUCCESS            |196.75          |FAST              |79.74    |45.34       |false      |
# |SERVER-005|200        |SUCCESS            |754.84          |SLOW              |19.47    |59.71       |false      |
# |SERVER-005|200        |SUCCESS            |203.66          |FAST              |51.79    |52.09       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# 25/10/13 23:49:32 ERROR TorrentBroadcast: Store broadcast broadcast_158 fail, remove all pieces of the broadcast
# -------------------------------------------
# Batch: 34
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-002|500        |INTERNAL_ERROR|721.49          |11.86    |34.34       |
# |SERVER-005|500        |INTERNAL_ERROR|613.98          |81.44    |48.27       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 34
# -------------------------------------------
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type    |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
# |SERVER-005|200        |SUCCESS       |908.82          |SLOW              |23.08    |75.16       |false      |
# |SERVER-004|200        |SUCCESS       |153.03          |FAST              |75.55    |47.47       |false      |
# |SERVER-004|200        |SUCCESS       |706.12          |SLOW              |59.83    |44.2        |false      |
# |SERVER-002|200        |SUCCESS       |856.05          |SLOW              |35.72    |83.36       |false      |
# |SERVER-003|200        |SUCCESS       |113.19          |FAST              |78.51    |68.75       |false      |
# |SERVER-001|200        |SUCCESS       |918.29          |SLOW              |36.26    |25.89       |false      |
# |SERVER-002|200        |SUCCESS       |917.91          |SLOW              |74.05    |23.36       |false      |
# |SERVER-002|500        |INTERNAL_ERROR|721.49          |SLOW              |11.86    |34.34       |true       |
# |SERVER-002|200        |SUCCESS       |201.96          |FAST              |11.65    |73.53       |false      |
# |SERVER-001|200        |SUCCESS       |849.58          |SLOW              |49.94    |72.7        |false      |
# |SERVER-001|200        |SUCCESS       |411.9           |MODERATE          |11.37    |59.4        |false      |
# |SERVER-001|200        |SUCCESS       |493.06          |MODERATE          |46.85    |75.71       |false      |
# |SERVER-005|200        |SUCCESS       |230.59          |FAST              |86.78    |49.77       |false      |
# |SERVER-001|200        |SUCCESS       |294.43          |FAST              |20.01    |46.78       |false      |
# |SERVER-005|500        |INTERNAL_ERROR|613.98          |SLOW              |81.44    |48.27       |true       |
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 35
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-004|500        |INTERNAL_ERROR|725.67          |16.53    |53.86       |
# +----------+-----------+--------------+----------------+---------+------------+

# %%
critical_alerts = analyzed_logs \
    .filter(col("is_critical") == True) \
    .select("server_id", "status_code", "error_type",
            "response_time_ms", "cpu_usage", "memory_usage")

query_critical = critical_alerts \
    .writeStream \
    .outputMode("append") \
    .format("console") \
    .option("truncate", "false") \
    .start()

query_critical.awaitTermination(5)
query_critical.stop()
# Out:
# -------------------------------------------
# Batch: 35
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-005|404        |NOT_FOUND          |759.01          |SLOW              |55.45    |31.19       |false      |
# |SERVER-001|200        |SUCCESS            |209.67          |FAST              |73.69    |36.88       |false      |
# |SERVER-004|200        |SUCCESS            |620.59          |SLOW              |75.51    |82.37       |false      |
# |SERVER-002|200        |SUCCESS            |604.19          |SLOW              |33.35    |35.07       |false      |
# |SERVER-003|404        |NOT_FOUND          |868.69          |SLOW              |48.06    |70.35       |false      |
# |SERVER-004|500        |INTERNAL_ERROR     |725.67          |SLOW              |16.53    |53.86       |true       |
# |SERVER-003|200        |SUCCESS            |301.11          |MODERATE          |23.21    |31.57       |false      |
# |SERVER-003|503        |SERVICE_UNAVAILABLE|295.89          |FAST              |79.17    |23.07       |false      |
# |SERVER-002|200        |SUCCESS            |187.57          |FAST              |31.38    |78.71       |false      |
# |SERVER-005|200        |SUCCESS            |746.57          |SLOW              |42.32    |32.75       |false      |
# |SERVER-001|404        |NOT_FOUND          |198.77          |FAST              |66.33    |39.7        |false      |
# |SERVER-004|200        |SUCCESS            |380.36          |MODERATE          |17.05    |50.87       |false      |
# |SERVER-002|200        |SUCCESS            |754.68          |SLOW              |86.17    |81.21       |false      |
# |SERVER-001|200        |SUCCESS            |637.19          |SLOW              |26.52    |30.92       |false      |
# |SERVER-003|200        |SUCCESS            |92.83           |FAST              |89.72    |40.16       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-003|500        |INTERNAL_ERROR|53.14           |68.23    |27.32       |
# |SERVER-001|404        |NOT_FOUND     |871.67          |94.22    |48.63       |
# |SERVER-001|200        |SUCCESS       |148.4           |94.4     |83.69       |
# |SERVER-001|200        |SUCCESS       |412.7           |91.94    |88.12       |
# |SERVER-002|500        |INTERNAL_ERROR|859.44          |30.85    |22.33       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +----------+-----------+----------+----------------+---------+------------+
# |server_id |status_code|error_type|response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+----------+----------------+---------+------------+
# |SERVER-002|200        |SUCCESS   |781.17          |92.96    |69.02       |
# |SERVER-001|200        |SUCCESS   |522.72          |88.77    |85.75       |
# +----------+-----------+----------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-001|200        |SUCCESS       |653.33          |90.84    |62.9        |
# |SERVER-002|500        |INTERNAL_ERROR|496.86          |42.47    |25.98       |
# |SERVER-002|200        |SUCCESS       |87.58           |91.71    |26.29       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-002|500        |INTERNAL_ERROR|377.24          |67.43    |50.79       |
# |SERVER-001|200        |SUCCESS       |895.22          |70.16    |89.67       |
# |SERVER-004|500        |INTERNAL_ERROR|891.42          |84.76    |37.96       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-002|200        |SUCCESS       |563.07          |90.23    |46.0        |
# |SERVER-001|200        |SUCCESS       |83.8            |91.79    |41.94       |
# |SERVER-005|500        |INTERNAL_ERROR|324.63          |33.65    |36.36       |
# |SERVER-002|500        |INTERNAL_ERROR|807.08          |72.59    |44.59       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-001|500        |INTERNAL_ERROR|583.95          |78.23    |32.72       |
# |SERVER-001|200        |SUCCESS       |443.76          |37.47    |87.41       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-003|500        |INTERNAL_ERROR|877.27          |74.95    |69.64       |
# |SERVER-001|500        |INTERNAL_ERROR|877.04          |60.8     |71.47       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 7
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-002|200        |SUCCESS       |51.21           |91.1     |29.46       |
# |SERVER-002|500        |INTERNAL_ERROR|91.22           |52.95    |52.93       |
# |SERVER-005|200        |SUCCESS       |678.41          |28.45    |88.52       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 8
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-004|200        |SUCCESS       |90.82           |74.36    |85.35       |
# |SERVER-001|500        |INTERNAL_ERROR|733.27          |40.99    |52.15       |
# |SERVER-002|200        |SUCCESS       |285.51          |93.03    |58.76       |
# |SERVER-001|500        |INTERNAL_ERROR|435.68          |16.29    |68.5        |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 9
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-002|200        |SUCCESS       |649.58          |92.18    |85.8        |
# |SERVER-001|500        |INTERNAL_ERROR|240.67          |51.08    |49.33       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 10
# -------------------------------------------
# +---------+-----------+----------+----------------+---------+------------+
# |server_id|status_code|error_type|response_time_ms|cpu_usage|memory_usage|
# +---------+-----------+----------+----------------+---------+------------+
# +---------+-----------+----------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 11
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-001|200        |SUCCESS       |189.14          |27.75    |86.35       |
# |SERVER-002|200        |SUCCESS       |356.61          |90.81    |77.74       |
# |SERVER-003|500        |INTERNAL_ERROR|415.73          |41.28    |52.12       |
# |SERVER-003|404        |NOT_FOUND     |573.93          |53.66    |89.37       |
# |SERVER-001|500        |INTERNAL_ERROR|426.47          |59.49    |84.28       |
# |SERVER-005|500        |INTERNAL_ERROR|677.47          |68.49    |34.7        |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 36
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-002|404        |NOT_FOUND          |647.15          |SLOW              |11.02    |78.08       |false      |
# |SERVER-003|500        |INTERNAL_ERROR     |523.77          |SLOW              |12.81    |20.46       |true       |
# |SERVER-004|200        |SUCCESS            |718.25          |SLOW              |41.95    |89.35       |true       |
# |SERVER-003|200        |SUCCESS            |713.28          |SLOW              |79.13    |84.49       |false      |
# |SERVER-001|500        |INTERNAL_ERROR     |692.62          |SLOW              |16.93    |28.76       |true       |
# |SERVER-002|503        |SERVICE_UNAVAILABLE|416.5           |MODERATE          |71.55    |51.57       |false      |
# |SERVER-001|404        |NOT_FOUND          |791.18          |SLOW              |72.06    |29.43       |false      |
# |SERVER-003|200        |SUCCESS            |526.04          |SLOW              |35.57    |33.28       |false      |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|300.79          |MODERATE          |38.83    |37.7        |false      |
# |SERVER-002|503        |SERVICE_UNAVAILABLE|493.39          |MODERATE          |22.26    |44.89       |false      |
# |SERVER-001|200        |SUCCESS            |319.56          |MODERATE          |27.54    |31.25       |false      |
# |SERVER-005|500        |INTERNAL_ERROR     |960.99          |SLOW              |79.43    |20.91       |true       |
# |SERVER-005|500        |INTERNAL_ERROR     |529.26          |SLOW              |45.05    |53.06       |true       |
# |SERVER-004|200        |SUCCESS            |151.59          |FAST              |30.15    |80.05       |false      |
# |SERVER-001|200        |SUCCESS            |278.85          |FAST              |71.71    |27.58       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 36
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-003|500        |INTERNAL_ERROR|523.77          |12.81    |20.46       |
# |SERVER-004|200        |SUCCESS       |718.25          |41.95    |89.35       |
# |SERVER-001|500        |INTERNAL_ERROR|692.62          |16.93    |28.76       |
# |SERVER-005|500        |INTERNAL_ERROR|960.99          |79.43    |20.91       |
# |SERVER-005|500        |INTERNAL_ERROR|529.26          |45.05    |53.06       |
# +----------+-----------+--------------+----------------+---------+------------+
# 25/10/13 23:49:44 ERROR WriteToDataSourceV2Exec: Data source write support MicroBatchWrite[epoch: 12, writer: ConsoleWriter[numRows=20, truncate=false]] is aborting.
# 25/10/13 23:49:44 ERROR WriteToDataSourceV2Exec: Data source write support MicroBatchWrite[epoch: 12, writer: ConsoleWriter[numRows=20, truncate=false]] aborted.
# -------------------------------------------
# Batch: 37
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-001|500        |INTERNAL_ERROR|704.89          |72.81    |55.88       |
# |SERVER-005|500        |INTERNAL_ERROR|362.61          |27.56    |21.21       |
# |SERVER-002|200        |SUCCESS       |630.24          |94.92    |85.12       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 37
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-001|200        |SUCCESS            |907.95          |SLOW              |41.68    |69.7        |false      |
# |SERVER-001|500        |INTERNAL_ERROR     |704.89          |SLOW              |72.81    |55.88       |true       |
# |SERVER-002|200        |SUCCESS            |910.44          |SLOW              |49.95    |65.53       |false      |
# |SERVER-005|404        |NOT_FOUND          |995.83          |SLOW              |67.88    |40.47       |false      |
# |SERVER-003|503        |SERVICE_UNAVAILABLE|573.69          |SLOW              |15.28    |74.64       |false      |
# |SERVER-005|200        |SUCCESS            |769.43          |SLOW              |65.55    |67.26       |false      |
# |SERVER-002|200        |SUCCESS            |715.58          |SLOW              |39.19    |51.07       |false      |
# |SERVER-004|200        |SUCCESS            |946.82          |SLOW              |40.03    |39.64       |false      |
# |SERVER-001|200        |SUCCESS            |994.98          |SLOW              |58.47    |50.34       |false      |
# |SERVER-002|200        |SUCCESS            |229.08          |FAST              |10.7     |51.85       |false      |
# |SERVER-003|200        |SUCCESS            |335.96          |MODERATE          |50.28    |76.81       |false      |
# |SERVER-004|503        |SERVICE_UNAVAILABLE|577.62          |SLOW              |38.45    |61.24       |false      |
# |SERVER-001|200        |SUCCESS            |843.65          |SLOW              |84.15    |47.65       |false      |
# |SERVER-005|500        |INTERNAL_ERROR     |362.61          |MODERATE          |27.56    |21.21       |true       |
# |SERVER-002|200        |SUCCESS            |630.24          |SLOW              |94.92    |85.12       |true       |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 38
# -------------------------------------------
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type    |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
# |SERVER-004|200        |SUCCESS       |451.35          |MODERATE          |54.67    |48.58       |false      |
# |SERVER-005|200        |SUCCESS       |257.16          |FAST              |39.56    |30.66       |false      |
# |SERVER-002|200        |SUCCESS       |637.82          |SLOW              |48.21    |40.68       |false      |
# |SERVER-003|404        |NOT_FOUND     |225.55          |FAST              |33.24    |44.7        |false      |
# |SERVER-005|500        |INTERNAL_ERROR|699.47          |SLOW              |57.91    |89.93       |true       |
# |SERVER-004|200        |SUCCESS       |940.9           |SLOW              |21.19    |58.65       |false      |
# |SERVER-004|200        |SUCCESS       |628.82          |SLOW              |51.71    |35.77       |false      |
# |SERVER-001|200        |SUCCESS       |780.81          |SLOW              |71.25    |80.78       |false      |
# |SERVER-004|500        |INTERNAL_ERROR|548.38          |SLOW              |32.1     |60.0        |true       |
# |SERVER-004|200        |SUCCESS       |243.68          |FAST              |59.45    |26.66       |false      |
# |SERVER-001|200        |SUCCESS       |186.77          |FAST              |93.07    |69.63       |true       |
# |SERVER-004|200        |SUCCESS       |717.15          |SLOW              |73.23    |87.82       |true       |
# |SERVER-003|500        |INTERNAL_ERROR|609.69          |SLOW              |88.84    |80.6        |true       |
# |SERVER-004|200        |SUCCESS       |323.37          |MODERATE          |32.88    |72.34       |false      |
# |SERVER-004|200        |SUCCESS       |293.27          |FAST              |60.57    |62.55       |false      |
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 38
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-005|500        |INTERNAL_ERROR|699.47          |57.91    |89.93       |
# |SERVER-004|500        |INTERNAL_ERROR|548.38          |32.1     |60.0        |
# |SERVER-001|200        |SUCCESS       |186.77          |93.07    |69.63       |
# |SERVER-004|200        |SUCCESS       |717.15          |73.23    |87.82       |
# |SERVER-003|500        |INTERNAL_ERROR|609.69          |88.84    |80.6        |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 39
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-005|200        |SUCCESS            |411.56          |MODERATE          |91.72    |56.58       |true       |
# |SERVER-005|200        |SUCCESS            |683.74          |SLOW              |18.07    |87.61       |true       |
# |SERVER-004|200        |SUCCESS            |929.92          |SLOW              |76.35    |25.78       |false      |
# |SERVER-005|200        |SUCCESS            |233.02          |FAST              |53.46    |49.56       |false      |
# |SERVER-004|200        |SUCCESS            |663.71          |SLOW              |11.02    |65.96       |false      |
# |SERVER-002|200        |SUCCESS            |926.08          |SLOW              |22.62    |81.63       |false      |
# |SERVER-003|500        |INTERNAL_ERROR     |422.72          |MODERATE          |86.72    |64.31       |true       |
# |SERVER-002|200        |SUCCESS            |437.0           |MODERATE          |79.22    |22.39       |false      |
# |SERVER-003|404        |NOT_FOUND          |166.74          |FAST              |55.54    |28.2        |false      |
# |SERVER-003|200        |SUCCESS            |460.24          |MODERATE          |57.75    |75.22       |false      |
# |SERVER-002|500        |INTERNAL_ERROR     |726.87          |SLOW              |67.52    |80.57       |true       |
# |SERVER-002|200        |SUCCESS            |203.96          |FAST              |87.11    |23.97       |false      |
# |SERVER-005|500        |INTERNAL_ERROR     |302.79          |MODERATE          |41.21    |34.86       |true       |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|794.48          |SLOW              |85.14    |86.95       |true       |
# |SERVER-004|200        |SUCCESS            |735.8           |SLOW              |44.42    |75.7        |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 39
# -------------------------------------------
# +----------+-----------+-------------------+----------------+---------+------------+
# |server_id |status_code|error_type         |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+-------------------+----------------+---------+------------+
# |SERVER-005|200        |SUCCESS            |411.56          |91.72    |56.58       |
# |SERVER-005|200        |SUCCESS            |683.74          |18.07    |87.61       |
# |SERVER-003|500        |INTERNAL_ERROR     |422.72          |86.72    |64.31       |
# |SERVER-002|500        |INTERNAL_ERROR     |726.87          |67.52    |80.57       |
# |SERVER-005|500        |INTERNAL_ERROR     |302.79          |41.21    |34.86       |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|794.48          |85.14    |86.95       |
# +----------+-----------+-------------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 40
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-003|500        |INTERNAL_ERROR|640.31          |30.96    |29.21       |
# |SERVER-002|200        |SUCCESS       |284.24          |61.21    |85.17       |
# |SERVER-002|500        |INTERNAL_ERROR|214.3           |35.22    |67.11       |
# |SERVER-004|200        |SUCCESS       |705.56          |51.6     |87.4        |
# |SERVER-002|500        |INTERNAL_ERROR|199.77          |62.86    |87.89       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 40
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-003|500        |INTERNAL_ERROR     |640.31          |SLOW              |30.96    |29.21       |true       |
# |SERVER-002|200        |SUCCESS            |790.96          |SLOW              |40.3     |35.88       |false      |
# |SERVER-005|200        |SUCCESS            |455.78          |MODERATE          |75.1     |61.88       |false      |
# |SERVER-001|503        |SERVICE_UNAVAILABLE|103.71          |FAST              |80.22    |72.01       |false      |
# |SERVER-002|200        |SUCCESS            |284.24          |FAST              |61.21    |85.17       |true       |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|102.8           |FAST              |64.4     |40.32       |false      |
# |SERVER-003|404        |NOT_FOUND          |284.68          |FAST              |69.87    |39.92       |false      |
# |SERVER-003|200        |SUCCESS            |552.74          |SLOW              |46.74    |67.75       |false      |
# |SERVER-002|500        |INTERNAL_ERROR     |214.3           |FAST              |35.22    |67.11       |true       |
# |SERVER-003|200        |SUCCESS            |246.39          |FAST              |36.6     |68.85       |false      |
# |SERVER-005|200        |SUCCESS            |347.25          |MODERATE          |50.86    |84.35       |false      |
# |SERVER-003|200        |SUCCESS            |691.35          |SLOW              |36.85    |28.67       |false      |
# |SERVER-004|200        |SUCCESS            |705.56          |SLOW              |51.6     |87.4        |true       |
# |SERVER-002|500        |INTERNAL_ERROR     |199.77          |FAST              |62.86    |87.89       |true       |
# |SERVER-002|200        |SUCCESS            |123.35          |FAST              |21.26    |26.8        |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 41
# -------------------------------------------
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type    |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
# |SERVER-001|500        |INTERNAL_ERROR|967.01          |SLOW              |23.17    |50.17       |true       |
# |SERVER-001|404        |NOT_FOUND     |817.22          |SLOW              |25.28    |86.55       |true       |
# |SERVER-005|200        |SUCCESS       |73.43           |FAST              |70.32    |38.61       |false      |
# |SERVER-004|200        |SUCCESS       |507.54          |SLOW              |69.85    |69.09       |false      |
# |SERVER-005|200        |SUCCESS       |513.78          |SLOW              |82.41    |20.26       |false      |
# |SERVER-002|200        |SUCCESS       |954.24          |SLOW              |81.75    |34.94       |false      |
# |SERVER-001|404        |NOT_FOUND     |495.56          |MODERATE          |46.24    |25.69       |false      |
# |SERVER-003|200        |SUCCESS       |640.31          |SLOW              |25.12    |85.87       |true       |
# |SERVER-001|404        |NOT_FOUND     |499.55          |MODERATE          |50.36    |83.66       |false      |
# |SERVER-003|200        |SUCCESS       |353.78          |MODERATE          |51.83    |81.55       |false      |
# |SERVER-005|200        |SUCCESS       |705.02          |SLOW              |22.25    |36.41       |false      |
# |SERVER-005|200        |SUCCESS       |752.32          |SLOW              |83.27    |71.9        |false      |
# |SERVER-004|200        |SUCCESS       |447.48          |MODERATE          |53.04    |41.51       |false      |
# |SERVER-004|200        |SUCCESS       |184.31          |FAST              |83.53    |24.75       |false      |
# |SERVER-002|200        |SUCCESS       |843.68          |SLOW              |53.25    |70.11       |false      |
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 41
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-001|500        |INTERNAL_ERROR|967.01          |23.17    |50.17       |
# |SERVER-001|404        |NOT_FOUND     |817.22          |25.28    |86.55       |
# |SERVER-003|200        |SUCCESS       |640.31          |25.12    |85.87       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 42
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-004|200        |SUCCESS            |147.7           |FAST              |47.17    |85.83       |true       |
# |SERVER-005|500        |INTERNAL_ERROR     |328.62          |MODERATE          |90.94    |60.15       |true       |
# |SERVER-002|200        |SUCCESS            |124.49          |FAST              |60.73    |25.79       |false      |
# |SERVER-002|200        |SUCCESS            |429.03          |MODERATE          |61.98    |28.76       |false      |
# |SERVER-001|200        |SUCCESS            |99.51           |FAST              |92.0     |69.24       |true       |
# |SERVER-001|200        |SUCCESS            |285.94          |FAST              |91.86    |44.5        |true       |
# |SERVER-002|200        |SUCCESS            |119.27          |FAST              |38.32    |70.28       |false      |
# |SERVER-002|404        |NOT_FOUND          |495.55          |MODERATE          |91.54    |29.45       |true       |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|266.34          |FAST              |17.31    |51.96       |false      |
# |SERVER-004|404        |NOT_FOUND          |670.64          |SLOW              |61.84    |76.65       |false      |
# |SERVER-003|200        |SUCCESS            |601.7           |SLOW              |28.71    |53.77       |false      |
# |SERVER-005|200        |SUCCESS            |188.07          |FAST              |90.13    |46.32       |true       |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|580.34          |SLOW              |75.42    |23.26       |false      |
# |SERVER-005|500        |INTERNAL_ERROR     |649.69          |SLOW              |17.36    |86.91       |true       |
# |SERVER-001|200        |SUCCESS            |528.47          |SLOW              |45.82    |29.5        |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 42
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-004|200        |SUCCESS       |147.7           |47.17    |85.83       |
# |SERVER-005|500        |INTERNAL_ERROR|328.62          |90.94    |60.15       |
# |SERVER-001|200        |SUCCESS       |99.51           |92.0     |69.24       |
# |SERVER-001|200        |SUCCESS       |285.94          |91.86    |44.5        |
# |SERVER-002|404        |NOT_FOUND     |495.55          |91.54    |29.45       |
# |SERVER-005|200        |SUCCESS       |188.07          |90.13    |46.32       |
# |SERVER-005|500        |INTERNAL_ERROR|649.69          |17.36    |86.91       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 43
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-005|200        |SUCCESS            |798.36          |SLOW              |93.2     |50.38       |true       |
# |SERVER-004|200        |SUCCESS            |266.7           |FAST              |51.16    |21.4        |false      |
# |SERVER-001|503        |SERVICE_UNAVAILABLE|88.45           |FAST              |23.87    |25.13       |false      |
# |SERVER-003|404        |NOT_FOUND          |312.32          |MODERATE          |27.08    |66.55       |false      |
# |SERVER-001|500        |INTERNAL_ERROR     |761.05          |SLOW              |53.31    |52.87       |true       |
# |SERVER-002|200        |SUCCESS            |280.09          |FAST              |40.37    |46.45       |false      |
# |SERVER-005|200        |SUCCESS            |151.55          |FAST              |18.99    |89.34       |true       |
# |SERVER-001|503        |SERVICE_UNAVAILABLE|437.25          |MODERATE          |72.16    |63.38       |false      |
# |SERVER-001|200        |SUCCESS            |581.99          |SLOW              |79.31    |27.95       |false      |
# |SERVER-001|200        |SUCCESS            |110.54          |FAST              |61.78    |20.81       |false      |
# |SERVER-003|200        |SUCCESS            |416.65          |MODERATE          |14.0     |80.93       |false      |
# |SERVER-001|200        |SUCCESS            |865.72          |SLOW              |76.73    |55.64       |false      |
# |SERVER-002|200        |SUCCESS            |230.05          |FAST              |21.0     |20.41       |false      |
# |SERVER-002|503        |SERVICE_UNAVAILABLE|298.34          |FAST              |86.53    |87.0        |true       |
# |SERVER-004|200        |SUCCESS            |922.6           |SLOW              |58.0     |56.45       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 43
# -------------------------------------------
# +----------+-----------+-------------------+----------------+---------+------------+
# |server_id |status_code|error_type         |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+-------------------+----------------+---------+------------+
# |SERVER-005|200        |SUCCESS            |798.36          |93.2     |50.38       |
# |SERVER-001|500        |INTERNAL_ERROR     |761.05          |53.31    |52.87       |
# |SERVER-005|200        |SUCCESS            |151.55          |18.99    |89.34       |
# |SERVER-002|503        |SERVICE_UNAVAILABLE|298.34          |86.53    |87.0        |
# +----------+-----------+-------------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 44
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-005|503        |SERVICE_UNAVAILABLE|214.82          |FAST              |50.37    |64.64       |false      |
# |SERVER-003|200        |SUCCESS            |222.39          |FAST              |35.6     |36.83       |false      |
# |SERVER-001|500        |INTERNAL_ERROR     |807.5           |SLOW              |83.66    |47.74       |true       |
# |SERVER-003|200        |SUCCESS            |197.79          |FAST              |64.7     |81.43       |false      |
# |SERVER-003|200        |SUCCESS            |931.06          |SLOW              |75.28    |46.93       |false      |
# |SERVER-002|500        |INTERNAL_ERROR     |662.0           |SLOW              |10.57    |80.69       |true       |
# |SERVER-002|503        |SERVICE_UNAVAILABLE|402.56          |MODERATE          |32.36    |41.09       |false      |
# |SERVER-001|200        |SUCCESS            |566.88          |SLOW              |86.75    |54.33       |false      |
# |SERVER-002|503        |SERVICE_UNAVAILABLE|238.56          |FAST              |69.97    |63.95       |false      |
# |SERVER-003|200        |SUCCESS            |913.17          |SLOW              |42.06    |70.9        |false      |
# |SERVER-005|200        |SUCCESS            |571.02          |SLOW              |12.15    |23.1        |false      |
# |SERVER-001|404        |NOT_FOUND          |521.54          |SLOW              |64.74    |76.07       |false      |
# |SERVER-005|200        |SUCCESS            |939.51          |SLOW              |63.33    |58.65       |false      |
# |SERVER-001|200        |SUCCESS            |680.21          |SLOW              |36.33    |58.99       |false      |
# |SERVER-003|200        |SUCCESS            |982.03          |SLOW              |65.98    |53.75       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 44
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-001|500        |INTERNAL_ERROR|807.5           |83.66    |47.74       |
# |SERVER-002|500        |INTERNAL_ERROR|662.0           |10.57    |80.69       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 45
# -------------------------------------------
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type    |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
# |SERVER-001|200        |SUCCESS       |866.26          |SLOW              |62.2     |45.35       |false      |
# |SERVER-001|500        |INTERNAL_ERROR|176.75          |FAST              |55.42    |85.97       |true       |
# |SERVER-005|200        |SUCCESS       |669.25          |SLOW              |40.06    |23.66       |false      |
# |SERVER-002|404        |NOT_FOUND     |891.36          |SLOW              |39.07    |41.89       |false      |
# |SERVER-004|200        |SUCCESS       |423.86          |MODERATE          |26.91    |52.41       |false      |
# |SERVER-003|404        |NOT_FOUND     |236.88          |FAST              |80.35    |35.81       |false      |
# |SERVER-004|404        |NOT_FOUND     |306.45          |MODERATE          |82.83    |38.65       |false      |
# |SERVER-001|500        |INTERNAL_ERROR|220.92          |FAST              |80.11    |86.78       |true       |
# |SERVER-003|200        |SUCCESS       |829.17          |SLOW              |81.63    |30.96       |false      |
# |SERVER-004|200        |SUCCESS       |693.6           |SLOW              |46.68    |52.02       |false      |
# |SERVER-002|200        |SUCCESS       |472.97          |MODERATE          |47.98    |83.99       |false      |
# |SERVER-004|200        |SUCCESS       |665.98          |SLOW              |24.65    |88.37       |true       |
# |SERVER-003|200        |SUCCESS       |190.34          |FAST              |71.91    |53.32       |false      |
# |SERVER-001|200        |SUCCESS       |822.8           |SLOW              |86.4     |69.67       |false      |
# |SERVER-004|200        |SUCCESS       |594.9           |SLOW              |18.92    |67.3        |false      |
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 45
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-001|500        |INTERNAL_ERROR|176.75          |55.42    |85.97       |
# |SERVER-001|500        |INTERNAL_ERROR|220.92          |80.11    |86.78       |
# |SERVER-004|200        |SUCCESS       |665.98          |24.65    |88.37       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 46
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-002|503        |SERVICE_UNAVAILABLE|278.63          |FAST              |58.95    |86.73       |true       |
# |SERVER-005|200        |SUCCESS            |434.07          |MODERATE          |53.47    |80.6        |false      |
# |SERVER-003|200        |SUCCESS            |236.21          |FAST              |53.81    |36.7        |false      |
# |SERVER-002|200        |SUCCESS            |961.45          |SLOW              |52.43    |44.96       |false      |
# |SERVER-004|200        |SUCCESS            |54.32           |FAST              |39.2     |29.51       |false      |
# |SERVER-002|200        |SUCCESS            |603.24          |SLOW              |35.1     |52.62       |false      |
# |SERVER-001|200        |SUCCESS            |721.28          |SLOW              |77.32    |76.92       |false      |
# |SERVER-004|200        |SUCCESS            |997.5           |SLOW              |78.24    |48.13       |false      |
# |SERVER-001|500        |INTERNAL_ERROR     |742.16          |SLOW              |48.58    |31.58       |true       |
# |SERVER-005|500        |INTERNAL_ERROR     |799.98          |SLOW              |94.19    |24.59       |true       |
# |SERVER-005|200        |SUCCESS            |519.49          |SLOW              |92.42    |52.18       |true       |
# |SERVER-005|404        |NOT_FOUND          |863.35          |SLOW              |77.74    |65.18       |false      |
# |SERVER-004|200        |SUCCESS            |191.31          |FAST              |59.34    |21.61       |false      |
# |SERVER-005|200        |SUCCESS            |77.05           |FAST              |36.52    |84.64       |false      |
# |SERVER-003|200        |SUCCESS            |860.16          |SLOW              |88.61    |76.22       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 46
# -------------------------------------------
# +----------+-----------+-------------------+----------------+---------+------------+
# |server_id |status_code|error_type         |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+-------------------+----------------+---------+------------+
# |SERVER-002|503        |SERVICE_UNAVAILABLE|278.63          |58.95    |86.73       |
# |SERVER-001|500        |INTERNAL_ERROR     |742.16          |48.58    |31.58       |
# |SERVER-005|500        |INTERNAL_ERROR     |799.98          |94.19    |24.59       |
# |SERVER-005|200        |SUCCESS            |519.49          |92.42    |52.18       |
# +----------+-----------+-------------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 47
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-001|200        |SUCCESS            |879.72          |SLOW              |94.17    |71.98       |true       |
# |SERVER-001|200        |SUCCESS            |880.28          |SLOW              |65.92    |58.4        |false      |
# |SERVER-001|200        |SUCCESS            |835.45          |SLOW              |17.56    |32.27       |false      |
# |SERVER-005|200        |SUCCESS            |598.24          |SLOW              |41.08    |22.04       |false      |
# |SERVER-003|200        |SUCCESS            |429.68          |MODERATE          |14.33    |40.26       |false      |
# |SERVER-002|200        |SUCCESS            |560.55          |SLOW              |13.69    |76.51       |false      |
# |SERVER-001|200        |SUCCESS            |237.13          |FAST              |76.87    |81.46       |false      |
# |SERVER-004|200        |SUCCESS            |234.81          |FAST              |22.42    |84.13       |false      |
# |SERVER-001|500        |INTERNAL_ERROR     |306.39          |MODERATE          |75.57    |29.0        |true       |
# |SERVER-003|200        |SUCCESS            |788.2           |SLOW              |47.94    |22.77       |false      |
# |SERVER-004|500        |INTERNAL_ERROR     |675.59          |SLOW              |58.31    |86.94       |true       |
# |SERVER-004|404        |NOT_FOUND          |929.73          |SLOW              |79.14    |83.65       |false      |
# |SERVER-002|503        |SERVICE_UNAVAILABLE|479.79          |MODERATE          |58.61    |38.0        |false      |
# |SERVER-005|500        |INTERNAL_ERROR     |194.59          |FAST              |45.02    |67.29       |true       |
# |SERVER-003|500        |INTERNAL_ERROR     |450.27          |MODERATE          |49.82    |82.0        |true       |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 47
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-001|200        |SUCCESS       |879.72          |94.17    |71.98       |
# |SERVER-001|500        |INTERNAL_ERROR|306.39          |75.57    |29.0        |
# |SERVER-004|500        |INTERNAL_ERROR|675.59          |58.31    |86.94       |
# |SERVER-005|500        |INTERNAL_ERROR|194.59          |45.02    |67.29       |
# |SERVER-003|500        |INTERNAL_ERROR|450.27          |49.82    |82.0        |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 48
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-001|200        |SUCCESS            |544.97          |SLOW              |68.93    |86.03       |true       |
# |SERVER-004|500        |INTERNAL_ERROR     |58.31           |FAST              |54.3     |48.84       |true       |
# |SERVER-001|200        |SUCCESS            |901.24          |SLOW              |88.64    |24.48       |false      |
# |SERVER-002|200        |SUCCESS            |364.93          |MODERATE          |94.05    |24.42       |true       |
# |SERVER-003|200        |SUCCESS            |178.21          |FAST              |45.74    |29.74       |false      |
# |SERVER-004|200        |SUCCESS            |309.05          |MODERATE          |18.31    |33.13       |false      |
# |SERVER-004|503        |SERVICE_UNAVAILABLE|957.17          |SLOW              |35.4     |74.77       |false      |
# |SERVER-002|404        |NOT_FOUND          |864.64          |SLOW              |15.63    |28.89       |false      |
# |SERVER-004|503        |SERVICE_UNAVAILABLE|368.25          |MODERATE          |19.63    |61.43       |false      |
# |SERVER-003|503        |SERVICE_UNAVAILABLE|583.44          |SLOW              |89.06    |60.71       |false      |
# |SERVER-004|200        |SUCCESS            |213.93          |FAST              |74.68    |36.52       |false      |
# |SERVER-003|500        |INTERNAL_ERROR     |133.56          |FAST              |52.76    |32.38       |true       |
# |SERVER-005|200        |SUCCESS            |155.72          |FAST              |74.61    |23.55       |false      |
# |SERVER-005|404        |NOT_FOUND          |684.84          |SLOW              |10.82    |65.01       |false      |
# |SERVER-001|200        |SUCCESS            |819.1           |SLOW              |38.52    |89.7        |true       |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 48
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-001|200        |SUCCESS       |544.97          |68.93    |86.03       |
# |SERVER-004|500        |INTERNAL_ERROR|58.31           |54.3     |48.84       |
# |SERVER-002|200        |SUCCESS       |364.93          |94.05    |24.42       |
# |SERVER-003|500        |INTERNAL_ERROR|133.56          |52.76    |32.38       |
# |SERVER-001|200        |SUCCESS       |819.1           |38.52    |89.7        |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 49
# -------------------------------------------
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type    |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
# |SERVER-003|200        |SUCCESS       |163.43          |FAST              |80.83    |63.71       |false      |
# |SERVER-004|200        |SUCCESS       |753.92          |SLOW              |49.0     |74.25       |false      |
# |SERVER-004|200        |SUCCESS       |292.43          |FAST              |81.06    |74.73       |false      |
# |SERVER-004|200        |SUCCESS       |251.63          |FAST              |64.69    |40.01       |false      |
# |SERVER-005|200        |SUCCESS       |501.56          |SLOW              |34.2     |83.8        |false      |
# |SERVER-001|200        |SUCCESS       |333.79          |MODERATE          |35.73    |39.1        |false      |
# |SERVER-003|200        |SUCCESS       |345.02          |MODERATE          |83.81    |51.28       |false      |
# |SERVER-005|500        |INTERNAL_ERROR|382.56          |MODERATE          |63.25    |43.33       |true       |
# |SERVER-001|200        |SUCCESS       |72.8            |FAST              |73.46    |24.57       |false      |
# |SERVER-005|200        |SUCCESS       |430.08          |MODERATE          |49.06    |31.12       |false      |
# |SERVER-002|200        |SUCCESS       |689.55          |SLOW              |71.79    |89.34       |true       |
# |SERVER-003|200        |SUCCESS       |260.07          |FAST              |74.75    |51.98       |false      |
# |SERVER-003|200        |SUCCESS       |522.74          |SLOW              |72.28    |40.24       |false      |
# |SERVER-005|404        |NOT_FOUND     |365.98          |MODERATE          |53.31    |56.08       |false      |
# |SERVER-001|404        |NOT_FOUND     |619.86          |SLOW              |82.05    |40.42       |false      |
# +----------+-----------+--------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 49
# -------------------------------------------
# +----------+-----------+--------------+----------------+---------+------------+
# |server_id |status_code|error_type    |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+--------------+----------------+---------+------------+
# |SERVER-005|500        |INTERNAL_ERROR|382.56          |63.25    |43.33       |
# |SERVER-002|200        |SUCCESS       |689.55          |71.79    |89.34       |
# +----------+-----------+--------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 50
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-003|200        |SUCCESS            |448.28          |MODERATE          |46.61    |42.74       |false      |
# |SERVER-004|200        |SUCCESS            |236.03          |FAST              |67.25    |63.34       |false      |
# |SERVER-004|200        |SUCCESS            |219.1           |FAST              |84.83    |29.44       |false      |
# |SERVER-002|200        |SUCCESS            |836.41          |SLOW              |25.28    |67.27       |false      |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|329.96          |MODERATE          |74.43    |35.09       |false      |
# |SERVER-001|500        |INTERNAL_ERROR     |753.88          |SLOW              |22.99    |64.75       |true       |
# |SERVER-002|200        |SUCCESS            |851.67          |SLOW              |53.27    |41.52       |false      |
# |SERVER-002|404        |NOT_FOUND          |361.46          |MODERATE          |23.0     |57.04       |false      |
# |SERVER-004|503        |SERVICE_UNAVAILABLE|154.51          |FAST              |36.21    |87.41       |true       |
# |SERVER-003|503        |SERVICE_UNAVAILABLE|615.29          |SLOW              |90.66    |67.66       |true       |
# |SERVER-001|200        |SUCCESS            |504.36          |SLOW              |33.53    |22.74       |false      |
# |SERVER-005|200        |SUCCESS            |589.96          |SLOW              |80.69    |69.63       |false      |
# |SERVER-002|200        |SUCCESS            |543.95          |SLOW              |58.27    |47.82       |false      |
# |SERVER-003|200        |SUCCESS            |598.18          |SLOW              |42.2     |26.81       |false      |
# |SERVER-004|200        |SUCCESS            |77.49           |FAST              |58.44    |86.11       |true       |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 50
# -------------------------------------------
# +----------+-----------+-------------------+----------------+---------+------------+
# |server_id |status_code|error_type         |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+-------------------+----------------+---------+------------+
# |SERVER-001|500        |INTERNAL_ERROR     |753.88          |22.99    |64.75       |
# |SERVER-004|503        |SERVICE_UNAVAILABLE|154.51          |36.21    |87.41       |
# |SERVER-003|503        |SERVICE_UNAVAILABLE|615.29          |90.66    |67.66       |
# |SERVER-004|200        |SUCCESS            |77.49           |58.44    |86.11       |
# +----------+-----------+-------------------+----------------+---------+------------+
#
# -------------------------------------------
# Batch: 51
# -------------------------------------------
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |server_id |status_code|error_type         |response_time_ms|performance_status|cpu_usage|memory_usage|is_critical|
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
# |SERVER-001|503        |SERVICE_UNAVAILABLE|668.23          |SLOW              |86.68    |86.72       |true       |
# |SERVER-003|200        |SUCCESS            |606.77          |SLOW              |49.97    |49.34       |false      |
# |SERVER-001|200        |SUCCESS            |537.73          |SLOW              |32.01    |21.37       |false      |
# |SERVER-004|500        |INTERNAL_ERROR     |914.72          |SLOW              |25.77    |53.87       |true       |
# |SERVER-004|200        |SUCCESS            |257.58          |FAST              |75.04    |80.1        |false      |
# |SERVER-005|200        |SUCCESS            |963.47          |SLOW              |87.53    |67.02       |false      |
# |SERVER-005|500        |INTERNAL_ERROR     |205.91          |FAST              |81.99    |69.28       |true       |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|280.94          |FAST              |58.1     |88.04       |true       |
# |SERVER-005|200        |SUCCESS            |495.74          |MODERATE          |57.86    |77.58       |false      |
# |SERVER-001|200        |SUCCESS            |899.39          |SLOW              |81.03    |55.76       |false      |
# |SERVER-003|200        |SUCCESS            |187.29          |FAST              |79.93    |81.72       |false      |
# |SERVER-002|200        |SUCCESS            |168.72          |FAST              |63.73    |57.54       |false      |
# |SERVER-002|200        |SUCCESS            |785.88          |SLOW              |23.45    |77.14       |false      |
# |SERVER-002|200        |SUCCESS            |223.88          |FAST              |14.11    |71.43       |false      |
# |SERVER-002|200        |SUCCESS            |486.2           |MODERATE          |11.02    |58.55       |false      |
# +----------+-----------+-------------------+----------------+------------------+---------+------------+-----------+
#
# -------------------------------------------
# Batch: 51
# -------------------------------------------
# +----------+-----------+-------------------+----------------+---------+------------+
# |server_id |status_code|error_type         |response_time_ms|cpu_usage|memory_usage|
# +----------+-----------+-------------------+----------------+---------+------------+
# |SERVER-001|503        |SERVICE_UNAVAILABLE|668.23          |86.68    |86.72       |
# |SERVER-004|500        |INTERNAL_ERROR     |914.72          |25.77    |53.87       |
# |SERVER-005|500        |INTERNAL_ERROR     |205.91          |81.99    |69.28       |
# |SERVER-005|503        |SERVICE_UNAVAILABLE|280.94          |58.1     |88.04       |
# +----------+-----------+-------------------+----------------+---------+------------+

# %%
sc.stop()
