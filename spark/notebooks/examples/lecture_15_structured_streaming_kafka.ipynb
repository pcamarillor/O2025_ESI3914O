# %% [markdown]
# # <center> <img src="../img/ITESOLogo.png" alt="ITESO" width="480" height="130"> </center>
# # <center> **Departamento de Electrónica, Sistemas e Informática** </center>
# ---
# ## <center> **Big Data** </center>
# ---
# ### <center> **Autumn 2025** </center>
# ---
# ### <center> **Examples on Structured Streaming (Kafka)** </center>
# ---
# **Profesor**: Pablo Camarillo Ramirez

# %% [markdown]
# # Install Kafka SERVER
#
# Go to `kafka` folder and run:
#
# `docker compose up -d`

# %% [markdown]
# # Create SparkSession
# ## Install Kafka connector

# %%
import findspark
findspark.init()

from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Examples on Structured Streaming (Kafka)") \
    .master("spark://spark-master:7077") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.13:4.0.0") \
    .config("spark.ui.port", "4040") \
    .getOrCreate()

sc = spark.sparkContext
sc.setLogLevel("INFO")

# Optimization (reduce the number of shuffle partitions)
spark.conf.set("spark.sql.shuffle.partitions", "5")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2.5.2/cache
# The jars for the packages stored in: /root/.ivy2.5.2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.13 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-dc337b0a-325d-48be-b11c-6cd79141c571;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.13;4.0.0 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.13;4.0.0 in central
# 	found org.apache.kafka#kafka-clients;3.9.0 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.10.7 in central
# 	found org.slf4j#slf4j-api;2.0.16 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.4.1 in central
# 	found org.apache.hadoop#hadoop-client-api;3.4.1 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.scala-lang.modules#scala-parallel-collections_2.13;1.2.0 in central
# 	found org.apache.commons#commons-pool2;2.12.0 in central
# :: resolution report :: resolve 198ms :: artifacts dl 6ms
# 	:: modules in use:
# 	com.google.code.findbugs#jsr305;3.0.0 from central in [default]
# 	org.apache.commons#commons-pool2;2.12.0 from central in [default]
# 	org.apache.hadoop#hadoop-client-api;3.4.1 from central in [default]
# 	org.apache.hadoop#hadoop-client-runtime;3.4.1 from central in [default]
# 	org.apache.kafka#kafka-clients;3.9.0 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.13;4.0.0 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.13;4.0.0 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.scala-lang.modules#scala-parallel-collections_2.13;1.2.0 from central in [default]
# 	org.slf4j#slf4j-api;2.0.16 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.10.7 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   11  |   0   |   0   |   0   ||   11  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-dc337b0a-325d-48be-b11c-6cd79141c571
# 	confs: [default]
# 	0 artifacts copied, 11 already retrieved (0kB/5ms)
# 25/10/10 00:52:44 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# # Create a data stream from a Kafka topic

# %%
# Create the remote connection
kafka_df = spark.readStream \
            .format("kafka") \
            .option("kafka.bootstrap.servers", "kafka:9093") \
            .option("subscribe", "kafka-example-1") \
            .load()

kafka_df.printSchema()

# Transform binary data to string
df_input = kafka_df.selectExpr("CAST(value AS STRING)")

# Send transformed data to the Sink
query_a = df_input.writeStream \
            .trigger(processingTime='1 second') \
            .outputMode("append") \
            .format("console") \
            .start()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)
# 25/10/10 00:55:33 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-85f88ff5-b45a-4727-b77a-4452a4f20930. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 25/10/10 00:55:33 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +-----+
# |value|
# +-----+
# +-----+
# 25/10/10 00:55:35 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 1000} milliseconds, but spent 1224 milliseconds
# 25/10/10 00:57:11 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 1000} milliseconds, but spent 1526 milliseconds
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +-----+
# |value|
# +-----+
# |hello|
# +-----+
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +------+
# | value|
# +------+
# |hello2|
# +------+

# %%
query_a.stop()
sc.stop()
# Out:
# 25/10/10 01:00:24 WARN DAGScheduler: Failed to cancel job group 2c43751c-c424-4286-a2f4-cf3d4311e927. Cannot find active jobs for it.
# 25/10/10 01:00:24 WARN DAGScheduler: Failed to cancel job group 2c43751c-c424-4286-a2f4-cf3d4311e927. Cannot find active jobs for it.

# %% [markdown]
# ## Add a Streaming listener

# %%
import findspark
findspark.init()

from pyspark.sql import SparkSession
from pcamarillor.streaming_listener import MyListener

spark = SparkSession.builder \
    .appName("Examples on Structured Streaming (Kafka)") \
    .master("spark://spark-master:7077") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.13:4.0.0") \
    .config("spark.ui.port", "4040") \
    .getOrCreate()

sc = spark.sparkContext

# Optimization (reduce the number of shuffle partitions)
spark.conf.set("spark.sql.shuffle.partitions", "5")

# Add custom listener
spark.streams.addListener(MyListener())
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2.5.2/cache
# The jars for the packages stored in: /root/.ivy2.5.2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.13 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-f4171cb9-3e32-4d8f-921f-44b06b6fb8e7;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.13;4.0.0 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.13;4.0.0 in central
# 	found org.apache.kafka#kafka-clients;3.9.0 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.10.7 in central
# 	found org.slf4j#slf4j-api;2.0.16 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.4.1 in central
# 	found org.apache.hadoop#hadoop-client-api;3.4.1 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.scala-lang.modules#scala-parallel-collections_2.13;1.2.0 in central
# 	found org.apache.commons#commons-pool2;2.12.0 in central
# :: resolution report :: resolve 264ms :: artifacts dl 8ms
# 	:: modules in use:
# 	com.google.code.findbugs#jsr305;3.0.0 from central in [default]
# 	org.apache.commons#commons-pool2;2.12.0 from central in [default]
# 	org.apache.hadoop#hadoop-client-api;3.4.1 from central in [default]
# 	org.apache.hadoop#hadoop-client-runtime;3.4.1 from central in [default]
# 	org.apache.kafka#kafka-clients;3.9.0 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.13;4.0.0 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.13;4.0.0 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.scala-lang.modules#scala-parallel-collections_2.13;1.2.0 from central in [default]
# 	org.slf4j#slf4j-api;2.0.16 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.10.7 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   11  |   0   |   0   |   0   ||   11  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-f4171cb9-3e32-4d8f-921f-44b06b6fb8e7
# 	confs: [default]
# 	0 artifacts copied, 11 already retrieved (0kB/6ms)
# 25/10/10 01:16:53 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Query started: 17fd8bdf-8b6e-49ca-8cc2-faec0baa94fb
# Query made progress: {
#   "id" : "17fd8bdf-8b6e-49ca-8cc2-faec0baa94fb",
#   "runId" : "5cac179c-d1e1-4121-abdb-10a1be1c2507",
#   "name" : null,
#   "timestamp" : "2025-10-10T01:19:30.281Z",
#   "batchId" : 0,
#   "batchDuration" : 2263,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "addBatch" : 1630,
#     "commitOffsets" : 85,
#     "getBatch" : 13,
#     "latestOffset" : 243,
#     "queryPlanning" : 268,
#     "triggerExecution" : 2262,
#     "walCommit" : 16
#   },
#   "stateOperators" : [ {
#     "operatorName" : "stateStoreSave",
#     "numRowsTotal" : 0,
#     "numRowsUpdated" : 0,
#     "allUpdatesTimeMs" : 38,
#     "numRowsRemoved" : 0,
#     "allRemovalsTimeMs" : 0,
#     "commitTimeMs" : 85,
#     "memoryUsedBytes" : 1200,
#     "numRowsDroppedByWatermark" : 0,
#     "numShufflePartitions" : 5,
#     "numStateStoreInstances" : 5,
#     "customMetrics" : {
#       "loadedMapCacheHitCount" : 0,
#       "loadedMapCacheMissCount" : 0,
#       "stateOnCurrentVersionSizeBytes" : 480
#     }
#   } ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[kafka-spark-example]]",
#     "startOffset" : null,
#     "endOffset" : {
#       "kafka-spark-example" : {
#         "0" : 44
#       }
#     },
#     "latestOffset" : {
#       "kafka-spark-example" : {
#         "0" : 44
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@459a0a5c",
#     "numOutputRows" : 0
#   }
# }
# Query started: e28865de-6d51-4626-8075-f7f00dce6eff
# Query made progress: {
#   "id" : "e28865de-6d51-4626-8075-f7f00dce6eff",
#   "runId" : "1c858fd2-e838-4414-9704-5a1a8bce04cd",
#   "name" : null,
#   "timestamp" : "2025-10-10T01:20:44.092Z",
#   "batchId" : 0,
#   "batchDuration" : 520,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "addBatch" : 425,
#     "commitOffsets" : 17,
#     "getBatch" : 1,
#     "latestOffset" : 24,
#     "queryPlanning" : 39,
#     "triggerExecution" : 519,
#     "walCommit" : 11
#   },
#   "stateOperators" : [ {
#     "operatorName" : "stateStoreSave",
#     "numRowsTotal" : 0,
#     "numRowsUpdated" : 0,
#     "allUpdatesTimeMs" : 19,
#     "numRowsRemoved" : 0,
#     "allRemovalsTimeMs" : 0,
#     "commitTimeMs" : 57,
#     "memoryUsedBytes" : 1200,
#     "numRowsDroppedByWatermark" : 0,
#     "numShufflePartitions" : 5,
#     "numStateStoreInstances" : 5,
#     "customMetrics" : {
#       "loadedMapCacheHitCount" : 0,
#       "loadedMapCacheMissCount" : 0,
#       "stateOnCurrentVersionSizeBytes" : 480
#     }
#   } ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[kafka-spark-example]]",
#     "startOffset" : null,
#     "endOffset" : {
#       "kafka-spark-example" : {
#         "0" : 44
#       }
#     },
#     "latestOffset" : {
#       "kafka-spark-example" : {
#         "0" : 44
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@459a0a5c",
#     "numOutputRows" : 0
#   }
# }
# Query started: 0e65d254-e8bf-4e06-90f0-c7289f96e457
# Query made progress: {
#   "id" : "0e65d254-e8bf-4e06-90f0-c7289f96e457",
#   "runId" : "6c615f95-8490-4097-a781-fc4172d2d882",
#   "name" : null,
#   "timestamp" : "2025-10-10T01:21:20.892Z",
#   "batchId" : 0,
#   "batchDuration" : 443,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "addBatch" : 360,
#     "commitOffsets" : 11,
#     "getBatch" : 1,
#     "latestOffset" : 23,
#     "queryPlanning" : 37,
#     "triggerExecution" : 443,
#     "walCommit" : 10
#   },
#   "stateOperators" : [ {
#     "operatorName" : "stateStoreSave",
#     "numRowsTotal" : 0,
#     "numRowsUpdated" : 0,
#     "allUpdatesTimeMs" : 20,
#     "numRowsRemoved" : 0,
#     "allRemovalsTimeMs" : 0,
#     "commitTimeMs" : 67,
#     "memoryUsedBytes" : 1200,
#     "numRowsDroppedByWatermark" : 0,
#     "numShufflePartitions" : 5,
#     "numStateStoreInstances" : 5,
#     "customMetrics" : {
#       "loadedMapCacheHitCount" : 0,
#       "loadedMapCacheMissCount" : 0,
#       "stateOnCurrentVersionSizeBytes" : 480
#     }
#   } ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[kafka-example-1]]",
#     "startOffset" : null,
#     "endOffset" : {
#       "kafka-example-1" : {
#         "0" : 2
#       }
#     },
#     "latestOffset" : {
#       "kafka-example-1" : {
#         "0" : 2
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@459a0a5c",
#     "numOutputRows" : 0
#   }
# }
# Query made progress: {
#   "id" : "0e65d254-e8bf-4e06-90f0-c7289f96e457",
#   "runId" : "6c615f95-8490-4097-a781-fc4172d2d882",
#   "name" : null,
#   "timestamp" : "2025-10-10T01:21:33.002Z",
#   "batchId" : 1,
#   "batchDuration" : 1582,
#   "numInputRows" : 1,
#   "inputRowsPerSecond" : 0.33322225924691773,
#   "processedRowsPerSecond" : 0.6321112515802781,
#   "durationMs" : {
#     "addBatch" : 1507,
#     "commitOffsets" : 16,
#     "getBatch" : 0,
#     "latestOffset" : 12,
#     "queryPlanning" : 14,
#     "triggerExecution" : 1582,
#     "walCommit" : 31
#   },
#   "stateOperators" : [ {
#     "operatorName" : "stateStoreSave",
#     "numRowsTotal" : 5,
#     "numRowsUpdated" : 5,
#     "allUpdatesTimeMs" : 46,
#     "numRowsRemoved" : 0,
#     "allRemovalsTimeMs" : 0,
#     "commitTimeMs" : 50,
#     "memoryUsedBytes" : 3072,
#     "numRowsDroppedByWatermark" : 0,
#     "numShufflePartitions" : 5,
#     "numStateStoreInstances" : 5,
#     "customMetrics" : {
#       "loadedMapCacheHitCount" : 10,
#       "loadedMapCacheMissCount" : 0,
#       "stateOnCurrentVersionSizeBytes" : 1552
#     }
#   } ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[kafka-example-1]]",
#     "startOffset" : {
#       "kafka-example-1" : {
#         "0" : 2
#       }
#     },
#     "endOffset" : {
#       "kafka-example-1" : {
#         "0" : 3
#       }
#     },
#     "latestOffset" : {
#       "kafka-example-1" : {
#         "0" : 3
#       }
#     },
#     "numInputRows" : 1,
#     "inputRowsPerSecond" : 0.33322225924691773,
#     "processedRowsPerSecond" : 0.6321112515802781,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@459a0a5c",
#     "numOutputRows" : 5
#   }
# }
# Query made progress: {
#   "id" : "0e65d254-e8bf-4e06-90f0-c7289f96e457",
#   "runId" : "6c615f95-8490-4097-a781-fc4172d2d882",
#   "name" : null,
#   "timestamp" : "2025-10-10T01:22:15.003Z",
#   "batchId" : 2,
#   "batchDuration" : 906,
#   "numInputRows" : 1,
#   "inputRowsPerSecond" : 0.33322225924691773,
#   "processedRowsPerSecond" : 1.1037527593818983,
#   "durationMs" : {
#     "addBatch" : 833,
#     "commitOffsets" : 16,
#     "getBatch" : 1,
#     "latestOffset" : 10,
#     "queryPlanning" : 18,
#     "triggerExecution" : 906,
#     "walCommit" : 28
#   },
#   "stateOperators" : [ {
#     "operatorName" : "stateStoreSave",
#     "numRowsTotal" : 7,
#     "numRowsUpdated" : 2,
#     "allUpdatesTimeMs" : 14,
#     "numRowsRemoved" : 0,
#     "allRemovalsTimeMs" : 0,
#     "commitTimeMs" : 51,
#     "memoryUsedBytes" : 3800,
#     "numRowsDroppedByWatermark" : 0,
#     "numShufflePartitions" : 5,
#     "numStateStoreInstances" : 5,
#     "customMetrics" : {
#       "loadedMapCacheHitCount" : 20,
#       "loadedMapCacheMissCount" : 0,
#       "stateOnCurrentVersionSizeBytes" : 1968
#     }
#   } ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[kafka-example-1]]",
#     "startOffset" : {
#       "kafka-example-1" : {
#         "0" : 3
#       }
#     },
#     "endOffset" : {
#       "kafka-example-1" : {
#         "0" : 4
#       }
#     },
#     "latestOffset" : {
#       "kafka-example-1" : {
#         "0" : 4
#       }
#     },
#     "numInputRows" : 1,
#     "inputRowsPerSecond" : 0.33322225924691773,
#     "processedRowsPerSecond" : 1.1037527593818983,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.execution.streaming.ConsoleTable$@459a0a5c",
#     "numOutputRows" : 7
#   }
# }

# %%
from pyspark.sql.functions import explode, split
# Create the remote connection
kafka_df = spark.readStream \
            .format("kafka") \
            .option("kafka.bootstrap.servers", "kafka:9093") \
            .option("subscribe", "kafka-example-1") \
            .load()


# Transform binary data to string
df_input = kafka_df.selectExpr("CAST(value AS STRING)")
df_input = df_input.select(explode(split(df_input.value, " ")).alias("word"))
df_input = df_input.groupBy("word").count()

# Send transformed data to the Sink
query_b = df_input.writeStream \
            .trigger(processingTime='3 second') \
            .outputMode("complete") \
            .format("console") \
            .start()


query_b.awaitTermination(300)
# Out:
# 25/10/10 01:21:20 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-15ba6b8f-c881-4921-b0c2-93f6325330de. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 25/10/10 01:21:20 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +----+-----+
# |word|count|
# +----+-----+
# +----+-----+
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +-----+-----+
# | word|count|
# +-----+-----+
# |   hi|    1|
# | name|    1|
# |pablo|    1|
# |   my|    1|
# |   is|    1|
# +-----+-----+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +-----+-----+
# | word|count|
# +-----+-----+
# |   hi|    1|
# | name|    1|
# |   my|    1|
# |   is|    1|
# |pablo|    1|
# |again|    1|
# |hello|    1|
# +-----+-----+
# False

# %%
query_b.stop()
sc.stop()
